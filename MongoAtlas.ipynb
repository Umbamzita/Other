# %%
#!pip install pymongo[srv]
#!pip install pymongo

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb+srv://m001-student:m001-mongodb-basics@cluster-cil2c.mongodb.net/test?retryWrites=true&w=majority")
db = client.test

# %%
client.server_info()
# Out:
# {'version': '4.0.13',
#  'gitVersion': 'bda366f0b0e432ca143bc41da54d8732bd8d03c0',
#  'modules': ['enterprise'],
#  'allocator': 'tcmalloc',
#  'javascriptEngine': 'mozjs',
#  'sysInfo': 'deprecated',
#  'versionArray': [4, 0, 13, 0],
#  'openssl': {'running': 'OpenSSL 1.0.1e-fips 11 Feb 2013',
#   'compiled': 'OpenSSL 1.0.1e-fips 11 Feb 2013'},
#  'buildEnvironment': {'distmod': 'rhel70',
#   'distarch': 'x86_64',
#   'cc': '/opt/mongodbtoolchain/v2/bin/gcc: gcc (GCC) 5.4.0',
#   'ccflags': '-fno-omit-frame-pointer -fno-strict-aliasing -ggdb -pthread -Wall -Wsign-compare -Wno-unknown-pragmas -Winvalid-pch -Werror -O2 -Wno-unused-local-typedefs -Wno-unused-function -Wno-deprecated-declarations -Wno-unused-but-set-variable -Wno-missing-braces -fstack-protector-strong -fno-builtin-memcmp',
#   'cxx': '/opt/mongodbtoolchain/v2/bin/g++: g++ (GCC) 5.4.0',
#   'cxxflags': '-Woverloaded-virtual -Wno-maybe-uninitialized -std=c++14',
# ...

# %%
try:
    print("MongoDB version is %s" %
            client.server_info()['version'])
except pymongo.errors.OperationFailure as error:
    print(error)
    quit(1)
# Out:
# MongoDB version is 4.0.13

# %%
my_db=client.test

# %%
my_db
# Out:
# Database(MongoClient(host=['cluster-shard-00-00-cil2c.mongodb.net:27017', 'cluster-shard-00-01-cil2c.mongodb.net:27017', 'cluster-shard-00-02-cil2c.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='Cluster-shard-0', ssl=True), 'test')

# %%
my_collection = my_db.foods

# %%
my_collection.insert_one({
    "_id": 1,
    "name": "pizza",
    "calories": 266,
    "fats": {
        "saturated": 4.5,
        "trans": 0.2
    },
    "protein": 11
})

# %%
my_collection.insert_one({
    "_id": 4,
    "name": "shamerma",
    "calories": 290,
    "fats": {
        "saturated": 5,
        "trans": 1
    },
    "protein": 15
})

# %%
my_collection.insert_many([
    {
        "_id": 2,
        "name": "hamburger",
        "calories": 295, "protein": 17,
        "fats": { "saturated": 5.0, "trans": 0.8 },
    },
    {
        "_id": 3,
        "name": "taco",
        "calories": 226, "protein": 9,
        "fats": { "saturated": 4.4, "trans": 0.5 },
    }
])

# %%
for item in my_collection.find():
    print(item["name"],item["fats"])
# Out:
# pizza {'saturated': 4.5, 'trans': 0.2}
# hamburger {'saturated': 5.0, 'trans': 0.8}
# taco {'saturated': 4.4, 'trans': 0.5}
# shamerma {'saturated': 5, 'trans': 1}

# %%
for item in my_collection.find({"calories" : {"$gte": 225, "$lt":266}}):
    print(item)
# Out:
# {'_id': 3, 'name': 'taco', 'calories': 226, 'protein': 9, 'fats': {'saturated': 4.4, 'trans': 0.5}}

# %%
for item in my_collection.find({"calories" : {"$gte": 225}}):
    print(item)
# Out:
# {'_id': 1, 'name': 'pizza', 'calories': 266, 'fats': {'saturated': 4.5, 'trans': 0.2}, 'protein': 11}
# {'_id': 2, 'name': 'hamburger', 'calories': 295, 'protein': 17, 'fats': {'saturated': 5.0, 'trans': 0.8}}
# {'_id': 3, 'name': 'taco', 'calories': 226, 'protein': 9, 'fats': {'saturated': 4.4, 'trans': 0.5}}
# {'_id': 4, 'name': 'shamerma', 'calories': 290, 'fats': {'saturated': 5, 'trans': 1}, 'protein': 15}

# %%
my_collection.delete_many({"calories" : {"$gte":300}})

# %%
db2=client.video

# %%
my_collection=db2.movieDetails

# %%
for item in my_collection.find({"genres": "Comedy"}):
    print(item["title"])
# Out:
# A Million Ways to Die in the West
# Wild Wild West
# Journey to the West
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# Love Actually
# Shakespeare in Love
# I Love You, Man
# Love & Other Drugs
# Punch-Drunk Love
# I Love You Phillip Morris
# Office Space
# Zathura: A Space Adventure
# Muppets from Space
# Turks in Space
# 2001: A Space Travesty
# Space Chimps
# The Adventures of Baron Munchausen
# The Adventures of Priscilla, Queen of the Desert
# Adventures in Babysitting
# The Adventures of Buckaroo Banzai Across the 8th Dimension
# The Adventures of Rocky & Bullwinkle
# The Rocky Horror Picture Show
# Best in Show
# Show Me Love
# There's No Business Like Show Business
# Show People
# Shaun of the Dead
# Dead Poets Society
# Evil Dead II
# Planet Terror
# Planet 51
# My Stepmother Is an Alien
# Alien Autopsy
# The Heartbreak Kid
# The Kid
# The Kid
# Honey I Blew Up the Kid
# Diary of a Wimpy Kid
# Trail of the Pink Panther
# The Hallelujah Trail
# ...

# %%
my_collection.find({"genres": "Comedy"}).count()
# Out:
# C:\Users\LORES\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# 749

# %%
my_collection2=db2.movieScratch

# %%
for item in my_collection2.find():
    print(item)
# Out:
# {'_id': ObjectId('5df7566a52ea5f18c0598be1'), 'title': 'Rocky', 'year': 1976, 'imdb': 'tt0075148'}
# {'_id': ObjectId('5df756ea52ea5f18c0598be2'), 'title': 'Creed', 'year': 2015, 'imdb': 'tt3076658'}

# %%
my_collection2.insert_one({'title' : 'Irlandec', 'year' : 2019, 'imdb' :'tt6077567'})

# %%
for item in my_collection2.find():
    print(item)
# Out:
# {'_id': ObjectId('5df7566a52ea5f18c0598be1'), 'title': 'Rocky', 'year': 1976, 'imdb': 'tt0075148'}
# {'_id': ObjectId('5df756ea52ea5f18c0598be2'), 'title': 'Creed', 'year': 2015, 'imdb': 'tt3076658'}
# {'_id': ObjectId('5df758649c0dbc5fbd70dd0f'), 'title': 'Irlandec', 'year': 2019, 'imdb': 'tt6077567'}
